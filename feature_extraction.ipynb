# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis
from sklearn.preprocessing import MinMaxScaler
from utils import *

# %%
data_path = 'dataverse_files/Dataset'
T_LIST = [i for i in range(1, 9)]
SENSOR_LIST = ['Accelerometer_Data', 'Acoustic_Emission_Data', 'Force_Data']
EXP_LIST = [i for i in range(1, 13)]

# %%
columns = ['T', 'Exp']
for sensor in ['Acc_X', 'Acc_Y', 'Acc_Z', 'AE', 'Force_X', 'Force_Y', 'Force_Z']:
    columns.append(sensor + '_Mean')
    columns.append(sensor + '_RMS')
    columns.append(sensor + '_Std')
    columns.append(sensor + '_SF')
    columns.append(sensor + '_Skewness')
    columns.append(sensor + '_Kurtosis')
    columns.append(sensor + '_Peak')
    columns.append(sensor + '_CF')
    columns.append(sensor + '_IF')
    columns.append(sensor + '_MSF')
    columns.append(sensor + '_MPS')
    columns.append(sensor + '_FC')
df = pd.DataFrame(columns=columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 86 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   T                 0 non-null      object
#  1   Exp               0 non-null      object
#  2   Acc_X_Mean        0 non-null      object
#  3   Acc_X_RMS         0 non-null      object
#  4   Acc_X_Std         0 non-null      object
#  5   Acc_X_SF          0 non-null      object
#  6   Acc_X_Skewness    0 non-null      object
#  7   Acc_X_Kurtosis    0 non-null      object
#  8   Acc_X_Peak        0 non-null      object
#  9   Acc_X_CF          0 non-null      object
#  10  Acc_X_IF          0 non-null      object
#  11  Acc_X_MSF         0 non-null      object
#  12  Acc_X_MPS         0 non-null      object
#  13  Acc_X_FC          0 non-null      object
#  14  Acc_Y_Mean        0 non-null      object
#  15  Acc_Y_RMS         0 non-null      object
#  16  Acc_Y_Std         0 non-null      object
#  17  Acc_Y_SF          0 non-null      object
#  18  Acc_Y_Skewness    0 non-null      object
#  19  Acc_Y_Kurtosis    0 non-null      object
#  20  Acc_Y_Peak        0 non-null      object
#  21  Acc_Y_CF          0 non-null      object
#  22  Acc_Y_IF          0 non-null      object
#  23  Acc_Y_MSF         0 non-null      object
#  24  Acc_Y_MPS         0 non-null      object
#  25  Acc_Y_FC          0 non-null      object
#  26  Acc_Z_Mean        0 non-null      object
#  27  Acc_Z_RMS         0 non-null      object
#  28  Acc_Z_Std         0 non-null      object
#  29  Acc_Z_SF          0 non-null      object
#  30  Acc_Z_Skewness    0 non-null      object
#  31  Acc_Z_Kurtosis    0 non-null      object
#  32  Acc_Z_Peak        0 non-null      object
#  33  Acc_Z_CF          0 non-null      object
#  34  Acc_Z_IF          0 non-null      object
#  35  Acc_Z_MSF         0 non-null      object
#  36  Acc_Z_MPS         0 non-null      object
#  37  Acc_Z_FC          0 non-null      object
#  38  AE_Mean           0 non-null      object
#  39  AE_RMS            0 non-null      object
#  40  AE_Std            0 non-null      object
#  41  AE_SF             0 non-null      object
#  42  AE_Skewness       0 non-null      object
#  43  AE_Kurtosis       0 non-null      object
#  44  AE_Peak           0 non-null      object
#  45  AE_CF             0 non-null      object
#  46  AE_IF             0 non-null      object
#  47  AE_MSF            0 non-null      object
#  48  AE_MPS            0 non-null      object
#  49  AE_FC             0 non-null      object
#  50  Force_X_Mean      0 non-null      object
#  51  Force_X_RMS       0 non-null      object
#  52  Force_X_Std       0 non-null      object
#  53  Force_X_SF        0 non-null      object
#  54  Force_X_Skewness  0 non-null      object
#  55  Force_X_Kurtosis  0 non-null      object
#  56  Force_X_Peak      0 non-null      object
#  57  Force_X_CF        0 non-null      object
#  58  Force_X_IF        0 non-null      object
#  59  Force_X_MSF       0 non-null      object
#  60  Force_X_MPS       0 non-null      object
#  61  Force_X_FC        0 non-null      object
#  62  Force_Y_Mean      0 non-null      object
#  63  Force_Y_RMS       0 non-null      object
#  64  Force_Y_Std       0 non-null      object
#  65  Force_Y_SF        0 non-null      object
#  66  Force_Y_Skewness  0 non-null      object
#  67  Force_Y_Kurtosis  0 non-null      object
#  68  Force_Y_Peak      0 non-null      object
#  69  Force_Y_CF        0 non-null      object
#  70  Force_Y_IF        0 non-null      object
#  71  Force_Y_MSF       0 non-null      object
#  72  Force_Y_MPS       0 non-null      object
#  73  Force_Y_FC        0 non-null      object
#  74  Force_Z_Mean      0 non-null      object
#  75  Force_Z_RMS       0 non-null      object
#  76  Force_Z_Std       0 non-null      object
#  77  Force_Z_SF        0 non-null      object
#  78  Force_Z_Skewness  0 non-null      object
#  79  Force_Z_Kurtosis  0 non-null      object
#  80  Force_Z_Peak      0 non-null      object
#  81  Force_Z_CF        0 non-null      object
#  82  Force_Z_IF        0 non-null      object
#  83  Force_Z_MSF       0 non-null      object
#  84  Force_Z_MPS       0 non-null      object
#  85  Force_Z_FC        0 non-null      object
# dtypes: object(86)
# memory usage: 132.0+ bytes

# %%
def feature_extraction(data):
    # 1) Mean Value
    mean_value = np.mean(np.abs(data))
    
    # 2) Root Mean Square (RMS)
    rms = np.sqrt(np.mean(np.square(data)))
    
    # 3) Standard Deviation
    std_dev = np.sqrt(np.mean(np.square(np.abs(data) - np.mean(data))))
    
    # 4) Shape Factor
    shape_factor = rms / mean_value
    
    # 5) Skewness
    skewness = np.mean(( (np.abs(data) - mean_value) / std_dev) **3)
    
    # 6) Kurtosis
    kurt = np.mean(( (np.abs(data) - mean_value) / std_dev) **4)
    
    # 7) Peak value
    peak_value = np.max(np.abs(data))
    
    # 8) Crest Factor
    crest_factor = peak_value / rms
    
    # 9) Impact Factor
    impact_factor = peak_value / mean_value
    
    # 10) Mean Square Frequency
    fft_data = np.fft.fft(data)
    freqs = np.fft.fftfreq(len(data))
    mean_square_frequency = np.sum((freqs**2) * np.abs(fft_data)**2) / np.sum(np.abs(fft_data)**2)
    
    # 11) Mean of Power Spectrum
    power_spectrum = np.abs(fft_data)**2
    mean_power_spectrum = np.mean(power_spectrum)
    
    # 12) Frequency Centroid
    frequency_centroid = np.sum(freqs * power_spectrum) / np.sum(power_spectrum)
    
    return (
        mean_value,
        rms,
        std_dev,
        shape_factor,
        skewness,
        kurt,
        peak_value,
        crest_factor,
        impact_factor,
        mean_square_frequency,
        mean_power_spectrum,
        frequency_centroid
    )

# %% [markdown]
# # 데이터 확인

# %%
for t in T_LIST:
    for exp in EXP_LIST:
        df_acc = pd.read_csv(data_path + f'/T{t}/Accelerometer_Data/Expt_{exp}.csv')
        df_ae = pd.read_csv(data_path + f'/T{t}/Acoustic_Emission_Data/Expt_{exp}.csv')
        df_force = pd.read_csv(data_path + f'/T{t}/Force_Data/Expt_{exp}.csv')

        if (len(df_acc.columns) != 3) or (len(df_ae.columns) != 1) or (len(df_force.columns) != 3):
            print(f'Column의 개수가 맞지 않습니다. -> T{t}/Expt_{exp}')
            continue


        df_acc.columns = ['X', 'Y', 'Z']
        df_ae.columns = ['AE']
        df_force.columns = ['X', 'Y', 'Z']
        columns = df_acc.columns.tolist() + df_ae.columns.tolist() + df_force.columns.tolist()

        expected_columns = set(['X', 'Y', 'Z', 'AE'])

        if set(columns) != expected_columns:
            print(f'Column명이 잘못된 것 같습니다. -> T{t}/Expt_{exp}')
            print(columns)
            continue

# %%
for t in T_LIST:
    for exp in EXP_LIST:
        df_acc = pd.read_csv(data_path + f'/T{t}/Accelerometer_Data/Expt_{exp}.csv')
        df_ae = pd.read_csv(data_path + f'/T{t}/Acoustic_Emission_Data/Expt_{exp}.csv')
        df_force = pd.read_csv(data_path + f'/T{t}/Force_Data/Expt_{exp}.csv')

        df_acc.columns = ['X', 'Y', 'Z']
        df_ae.columns = ['AE']
        df_force.columns = ['X', 'Y', 'Z']

        if t == 3: #T3
            df_acc = df_acc.iloc[[i for i in range(6)] + [i for i in range(7,)],:]
            df_ae = df_ae.iloc[[i for i in range(6)] + [i for i in range(7,)],:]
            df_force = df_force.iloc[[i for i in range(6)] + [i for i in range(7,)],:]
        
        acc_x = df_acc['X']
        acc_y = df_acc['Y']
        acc_z = df_acc['Z']
        ae = df_ae['AE']
        force_x = df_force['X']
        force_y = df_force['Y']
        force_z = df_force['Z']

        
        
        acc_x_features = feature_extraction(acc_x)
        acc_y_features = feature_extraction(acc_y)
        acc_z_features = feature_extraction(acc_z)
        ae_features = feature_extraction(ae)
        force_x_features = feature_extraction(force_x)
        force_y_features = feature_extraction(force_y)
        force_z_features = feature_extraction(force_z)
        
        df.loc[len(df)] = [t, exp] + list(acc_x_features) + list(acc_y_features) + list(acc_z_features) + list(ae_features) + list(force_x_features) + list(force_y_features) + list(force_z_features)

# %%
tool_values = []
for i in T_LIST:
    df_tool = pd.read_csv(data_path + f'/T{t}/Tool_Wear_Values/T{t}_Tool_wear_values_for_all_Experiments.csv')
    # df_tool.info()
    tool_values.extend(df_tool.iloc[:, 1].values.tolist())

print(len(tool_values) == 96)
if len(tool_values) == 96:
    df['Tool_Wear'] = tool_values
# Out:
# True

# %%
df.head()
# Out:
#      T  Exp  Acc_X_Mean  Acc_X_RMS  Acc_X_Std  Acc_X_SF  Acc_X_Skewness  \
# 0  1.0  1.0    0.163240   0.244874   0.245366  1.500083        0.964630
# 1  1.0  2.0    0.183691   0.333134   0.335844  1.813554        2.018646
# 2  1.0  3.0    0.205349   0.325852   0.329426  1.586824        1.623629
# 3  1.0  4.0    0.201121   0.290789   0.293823  1.445837        0.768127
# 4  1.0  5.0    0.277956   0.403891   0.407729  1.453075        0.874744
#
#    Acc_X_Kurtosis  Acc_X_Peak   Acc_X_CF  ...  Force_Z_SF  Force_Z_Skewness  \
# 0        3.379572    2.343314   9.569487  ...    1.068862         -0.426066
# 1        9.257788    3.769139  11.314184  ...    1.040572         -0.947635
# 2        8.827150    4.270499  13.105628  ...    1.029084         -1.514916
# 3        2.361443    2.228655   7.664173  ...    1.036051         -0.825096
# 4        3.128520    3.939819   9.754655  ...    1.044743         -0.236622
#
#    Force_Z_Kurtosis  Force_Z_Peak  Force_Z_CF  Force_Z_IF  Force_Z_MSF  \
# 0          3.010540       283.203    2.286155    2.443584     0.001006
# 1          5.196432       352.783    2.043478    2.126386     0.000655
# 2          6.804483       402.832    2.153526    2.216159     0.000532
# 3          5.563507       401.611    1.878854    1.946588     0.000437
# 4          5.474715       552.979    2.366853    2.472753     0.000689
#
#     Force_Z_MPS    Force_Z_FC  Tool_Wear
# 0  8.286788e+08  3.409825e-19      96.54
# 1  1.609449e+09  1.755663e-19     121.06
# 2  1.889511e+09  1.495440e-19     123.18
# 3  2.467329e+09 -3.435677e-19     133.43
# 4  2.947654e+09 -1.917219e-19     137.29
#
# [5 rows x 87 columns]

# %%
df.to_csv('feature_extraction_v2.csv', index=False)
